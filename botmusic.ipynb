# %%
# !pip install yt-dlp yt-dlp-youtube-oauth2
# !yt-dlp --username oauth2 --password "" https://youtube.com
# Out:
# ...
# [youtube:recommended+oauth2] oauth2: Initializing OAuth2 Authorization Flow
# [youtube:recommended+oauth2] To give yt-dlp access to your account, go to  https://www.google.com/device  and enter code  VPYS-LFJR
# ERROR: [youtube:recommended+oauth2] Unable to download JSON metadata: HTTP Error 400: Bad Request (caused by <HTTPError 400: Bad Request>)
